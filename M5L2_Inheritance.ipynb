# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M5L2_Inheritance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Object-oriented programming. Inheritance
#
# [PPT M5L2 ENG](https://docs.google.com/presentation/d/1xAf2WnfqjJEUU1AqaAixnxhqEE1MNZgG8spekLr6lPA/edit?usp=sharing)
#
# [PPT M5L2 IND](https://docs.google.com/presentation/d/1RzXECxD48wCzg9RlZ-NrrYeWCquDnxnthLdDAY0gwOE/edit?usp=sharing)

# %%
# cara bikin class
class Mobil():
  # constructor --> metode yang otomatis dipanggil waktu bikin objek
  def __init__(self, merk, logo, warna):
    # properti
    self.merk = merk
    self.logo = logo
    self.warna = warna

  # metode --> apa yg bisa dilakukan
  def jalan(self):
    print('Mobil', self.warna, 'berjalan')

# bikin objek
mobil_kuning = Mobil('toyota', 'T', 'kuning')

# manggil metode
mobil_kuning.jalan()
# Out:
# Mobil kuning berjalan

# %% [markdown]
# ## ENG

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## INDO

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Contoh 2

# %%
# kelas induk (superclass)
class Binatang():
  def __init__(self, hidup, suara, makanan):
    # properti
    self.hidup = hidup
    self.suara = suara
    self.makanan = makanan

  def gerak(self):
    print('hewan ini bergerak')

# %%
# kelas keturunan dr kelas Binatang
class Mamalia(Binatang):
  # konstruktor
  def __init__(self, hidup, suara, makanan, jumlah_kaki):
    super().__init__(hidup, suara, makanan)
    self.jumlah_kaki = jumlah_kaki

  # metode
  def melahirkan(self):
    print('mamalia melahirkan')

# %%
# bikin objek
kucing = Mamalia('ya', 'meong', 'ikan', 4)

# manggil properti
kucing.gerak()
kucing.melahirkan()
# Out:
# hewan ini bergerak
# mamalia melahirkan

# %%
ikan = Binatang('ya', 'blup', 'plankton')

ikan.melahirkan()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-4709944ff5ca> in <cell line: 3>()
#       1 ikan = Binatang('ya', 'blup', 'plankton')
#       2
# ----> 3 ikan.melahirkan()
#
# AttributeError: 'Binatang' object has no attribute 'melahirkan'

# %% [markdown]
# ## Contoh

# %%
# class induk (superclass)
class Mobil():
  # constructor --> fungsi yang otomatis dipanggil waktu kita bikin objek
  def __init__(self, warna, tipe, merk = 'toyota'):
    # karakteristik/properties
    self.warna = warna
    self.tipe = tipe
    self.merk = merk

  # actions
  def jalan(self):
    print('Mobil warna', self.warna, 'berjalan')

# %% [markdown]
# ### Tidak ada tambahan properties

# %%
# class anak --> Mobil Sport
class Mobil_Sport(Mobil):
  # constructor
  def __init__(self, warna, tipe, merk):
    super.__init__(warna, tipe, merk)

  # method lain

# %%
# class anak --> Mobil Sport
class Mobil_Sport(Mobil):
  # properties nya sama kyk Mobil
  def ngebut(self):
    print(self.warna, 'ngebuutt')

# bikin objek
mobil_kuning = Mobil_Sport('kuning', 'sport', 'ferrari')

mobil_kuning.ngebut()
mobil_kuning.jalan()
# Out:
# kuning ngebuutt
# Mobil warna kuning berjalan

# %%
mobil_merah = Mobil_Sport('merah', 'sport', 'ferrari')

mobil_merah.ngebut()
# Out:
# merah ngebuutt

# %% [markdown]
# ### **Nambahin** properties

# %%
class Mobil_Sedan(Mobil):
  # constructor
  def __init__(self, warna, tipe, merk, jumlah_kursi):
    # manggil constructor class induknya
    super.__init__(warna, tipe, merk)
    self.jumlah_kursi = jumlah_kursi # property tambahan

# %% [markdown]
# # Knight and Dragon

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Create class Hero
class Hero():

  # constructor
  def __init__(self, name, health, armor, power):
       self.name = name
       self.health = health
       self.armor = armor
       self.power = power
       self.new = True

  # print info method --> nampilin info
  def print_info(self):
    print('Greet the hero ->', self.name)
    print('Health level:', self.health, '\n')
    # continue ..

  # method untuk menyerang
  def strike(self, enemy): # parameter berupa objek
    # armor musuh berkurang sesuai power hero
    enemy.armor -= self.power
    # kalo armor musuh (-) maka health yang berkurang
    if enemy.armor < 0:
      enemy.health += enemy.armor # agar health berkurang sesuai armor
      enemy.armor = 0

# %%
# class Warrior (turunan dari class Hero)
class Warrior(Hero):
    # greeting
    def hello(self):
        print('-> NEW HERO! A skilled warrior appears from the forest depths', self.name )

    #method for displaying a text description of the attack on the screen
    def attack(self, enemy):
        print(self.name , 'attacks fearlessly', enemy.name )
        print('The fight outcome for', self.name )
        self.print_info()
        print('The fight outcome for', enemy.name )
        enemy.print_info()

# %%
# class Dragon (turunan dari class Hero)
class Dragon(Hero):
  def hello(self):
    print()
    # continue yourself ...

  def attack(self, enemy):
    print()
    # continue yourself ...

# %% [markdown]
# Game Loop

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Contoh Penyelesaian

# %%
from random import randint

class Hero():
    def __init__(self, name, health, armor, power):
       self.name = name
       self.health = health
       self.armor = armor
       self.power = power
       self.new = True
    #printing character info:
    def print_info(self):
       print('Health level:', self.health)
       print('Armor class:', self.armor)

    #check if the character is alive
    def check_alive(self):
        if self.health > 0:
            return True
        else:
            return False

    #striking:
    def strike(self, enemy):
       enemy.armor -= self.power
       if enemy.armor < 0:
           enemy.health += enemy.armor
           enemy.armor = 0

# class
class Warrior(Hero):
    def hello(self):
        if self.new:
            print('-> NEW HERO! A skilled warrior appears from the forest depths', self.name )
            self.new = False
        else:
            print('The martial', self.name, 'appears again')

    #method for displaying a text description of the attack on the screen
    def attack(self, enemy):
        print(self.name , 'fearlessly pounces on', enemy.name )
        print('The fight outcome for', self.name )
        self.print_info()
        print('The fight outcome for', enemy.name )
        enemy.print_info()

class Dragon(Hero):
    def hello(self):
        if self.new:
            print('-> NEW HERO! The fierce dragon', self.name, ' descends from the sky')
            self.new = False
        else:
            print('Once again the furious dragon', self.name, 'appears before us')

    def attack(self, enemy):
        print(self.name , 'directs a stream of deadly fire at', enemy.name )
        print('The fight outcome for', self.name )
        self.print_info()
        print('The fight outcome for', enemy.name )
        enemy.print_info()


# bikin objek knight
knight = Warrior('Richard', 50, 25, 20)
print('Hail to thee, good knight', knight.name )
print('You are standing at the entrance to the forest full of deadly dangers. Are you ready to go there and fight the enemies (yes/no)?')

answer = input()

# nentuin play / no
if answer == 'yes':
    play = True
    print('\n***Let the fight begin!*** \n')
else:
    play = False

# List of enemies
enemies = list()
enemies.append(Warrior('Peter', 15, 0, 10))
enemies.append(Warrior('Sergio', 10, 15, 5))
enemies.append(Dragon('Drogon', 1, 25, 60))
enemies.append(Dragon('Viserion', 1, 10, 30))


# Game Loop
while play:
    #we determine who the knight will fight with
    #we take the length of the list as an index, because after killing enemies, the list will shrink
    enemy = enemies[randint(0,len(enemies)-1)]
    enemy.hello()
    enemy.print_info()

    is_attack = input('Join the fight (yes/no)?')
    if is_attack == 'yes':
        if randint(0,1) == 1:
            fighters = [knight, enemy]
        else:
            fighters = [enemy, knight]
        fighters [0].strike(fighters[1])
        fighters [0].attack(fighters[1])
    print('---')

    #check if the current enemy is dead and if so, remove them from the list
    if enemy.check_alive() == False:
        print(enemy.name , 'died by hand of', knight.name, '\n')
        enemies.remove(enemy)

    #we check the conditions of the game end (the Knight died or all the enemies were killed)
    if knight.check_alive() == False:
        print('The brave knight', knight.name , 'died in battle with enemies')
        play = False
    if len(enemies) == 0:
        print('The brave Knight', knight.name , 'defeated all the enemies!')
        play = False

print('That is the end of the fairy tale')
# Out:
# Hail to thee, good knight Richard
# You are standing at the entrance to the forest full of deadly dangers. Are you ready to go there and fight the enemies (yes/no)?
# yes
#
# ***Let the fight begin!***
#
# -> NEW HERO! The fierce dragon Drogon  descends from the sky
# Health level: 1
# Armor class: 25
# Join the fight (yes/no)?yes
# Drogon directs a stream of deadly fire at Richard
# The fight outcome for Drogon
# Health level: 1
# Armor class: 25
# The fight outcome for Richard
# Health level: 15
# Armor class: 0
# ---
# Once again the furious dragon Drogon appears before us
# Health level: 1
# Armor class: 25
# Join the fight (yes/no)?yes
# Richard fearlessly pounces on Drogon
# The fight outcome for Richard
# Health level: 15
# Armor class: 0
# The fight outcome for Drogon
# Health level: 1
# Armor class: 5
# ---
# -> NEW HERO! The fierce dragon Viserion  descends from the sky
# Health level: 1
# Armor class: 10
# Join the fight (yes/no)?yes
# Richard fearlessly pounces on Viserion
# The fight outcome for Richard
# Health level: 15
# Armor class: 0
# The fight outcome for Viserion
# Health level: -9
# Armor class: 0
# ---
# Viserion died by hand of Richard
#
# -> NEW HERO! A skilled warrior appears from the forest depths Peter
# Health level: 15
# Armor class: 0
# Join the fight (yes/no)?yes
# Peter fearlessly pounces on Richard
# The fight outcome for Peter
# Health level: 15
# Armor class: 0
# The fight outcome for Richard
# Health level: 5
# Armor class: 0
# ---
# Once again the furious dragon Drogon appears before us
# Health level: 1
# Armor class: 5
# Join the fight (yes/no)?yes
# Drogon directs a stream of deadly fire at Richard
# The fight outcome for Drogon
# Health level: 1
# Armor class: 5
# The fight outcome for Richard
# Health level: -55
# Armor class: 0
# ---
# The brave knight Richard died in battle with enemies
# That is the end of the fairy tale
