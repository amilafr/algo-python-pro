# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M2L3_Loops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Loop
#
# – a command that executes actions given as long as a certain logical expression (condition) remains true.
#
# [PPT M2L3 ENG](https://docs.google.com/presentation/d/1o8gpbmuW3KFaYpshbh8qqk0DacGTiOrtrCYXPmVCGSI/edit?usp=sharing)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Loop : While
#
# **Repeat until** --> gatau berapa kali perulangannya

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# while --> berulang terus selama kondisi True

userInput = input('input: ')

while userInput != 'off':
  print('haiii')
  userInput = input('input: ')
# Out:
# input: yes
# haiii
# input: tes
# haiii
# input: haloo
# haiii
# input: olaa
# haiii
# input: off

# %%
price = int(input('Enter the next price (0 to finish):'))
total_price = 0

while price != 0:
   total_price += price
   price = int(input('Enter the next price (0 to finish):'))

print('Total price without discount:', total_price)

total_price = total_price * 0.9
print('Total price with discount:', total_price)
# Out:
# Enter the next price (0 to finish):100
# Enter the next price (0 to finish):20
# Enter the next price (0 to finish):0
# Total price without discount: 120
# Total price with discount: 108.0

# %% [markdown]
# # Loop with Counter
#
# **Counter** --> this is a variable storing the number of steps of a certain loop.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
password = input('Input password: ')
attempts = 1

while password != 'hola':
  print('Error')
  password = input('Input password: ')
  attempts += 1

print('Total attempts:', attempts)
# Out:
# Input password: hai
# Error
# Input password: sisi
# Error
# Input password: hola
# Total attempts: 3

# %%
# rata-rata
total = 0
counter = 0

angka = int(input('Masukkan angka (0 - stop): '))

while angka != 0:
  total += angka
  counter += 1
  print('jumlah angka:', counter)
  angka = int(input('Masukkan angka (0 - stop): '))

mean = total / counter
print('hasilnya:', mean)
# Out:
# Masukkan angka (0 - stop): 100
# jumlah angka: 1
# Masukkan angka (0 - stop): 200
# jumlah angka: 2
# Masukkan angka (0 - stop): 300
# jumlah angka: 3
# Masukkan angka (0 - stop): 0
# hasilnya: 200.0

# %% [markdown]
# # Kunci Jawaban
