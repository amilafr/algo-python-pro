# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M3L1_Functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Functions

# %% [markdown]
# [PPT M3L1](https://docs.google.com/presentation/d/1BO7CipMdVofkaTJ5nVueklYKqUm8Q08_iA2OrNgeT1Y/edit?usp=sharing)
#
# Function is
# an algorithm that is composed in a programming language and has a unique name.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Creating Functions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Without Parameter

# %%
def print_label():
       print('THE SUCCESS CENTER')
       print('Name: ____')
       print('Course: ____')
       print('Group: ______')

print('Label printing machine')
amount = int(input('Number of students:'))
for i in range (amount):
  print_label()
print('Done! Take your labels.')
# Out:
# Label printing machine
# Number of students:2
# THE SUCCESS CENTER
# Name: ____
# Course: ____
# Group: ______
# THE SUCCESS CENTER
# Name: ____
# Course: ____
# Group: ______
# Done! Take your labels.

# %% [markdown]
# With Parameter

# %%
def print_label(name):
   print('THE SUCCESS CENTER')
   print('Name:', name)
   print('Course: English')

print('Test worksheets printing')
amount = int(input('Number of students:'))
for i in range(amount):
   name = input('Student name:')
   print_label(name)
print('Done! Take the sheets.')
# Out:
# Test worksheets printing
# Number of students:3
# Student name:mike
# THE SUCCESS CENTER
# Name: mike
# Course: English
# Student name:jane
# THE SUCCESS CENTER
# Name: jane
# Course: English
# Student name:jess
# THE SUCCESS CENTER
# Name: jess
# Course: English
# Done! Take the sheets.

# %% [markdown]
# # Returning a Value

# %%
def get_result(score):
  if score >= 50 and score < 100:
      result = 'grade III certificate'
  elif score >= 100 and score < 200:
      result = 'grade II certificate'
  elif score >= 200:
      result = 'grade I certificate'
  else:
      result = 'appreciation letter'
  return result

name = input('Student name:')
score = int(input('Points earned:'))
result = get_result(score)
print(name, '-', result)
if result == 'grade I certificate':
   print('You receive a gift — a book shop voucher ')
# Out:
# Student name:Nana
# Points earned:80
# Nana - grade III certificate
