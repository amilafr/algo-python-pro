# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M1L3_String.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #String

# %%
kalimat = 'Aku senang belajar python'
#index dimulai dari 0 --> 'A'

# %% [markdown]
# Panjang string --> fungsi len()

# %%
#cari tahu panjang dari string (jumlah karakter) --> fungsi len()
panjang_kalimat = len(kalimat)
print(panjang_kalimat)
# Out:
# 25

# %%
#get karakter di index tertentu
cari = kalimat[1] # nama_variabel[index]
print(cari)
# Out:
# k

# %%
#nyari pake rentang --> slicing
slicing = kalimat[0:6] #index 0 sampai <3
print(slicing)
# Out:
# Aku se

# %%
#nyari kata di string
search = kalimat.find('python')
print('python:', search) #output --> index karakter pertama ('p')

gaada = kalimat.find('pagi')
print('kalo gaada:', gaada)
# Out:
# python: 19
# kalo gaada: -1

# %%
#bikin semua hurufnya jadi kecil (lowercase) --> method .lower()
kalimat = kalimat.lower()
kata_aku = kalimat.find('aku')
print(kata_aku)
# Out:
# 0

# %% [markdown]
# #Perbedaan operator untuk String dan Integer
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Strange program

# %%
rate1 = input('masukkan rating1:')
rate2 = input('masukkan rating2:')

total = rate1 + rate2
print(total)

# string + string --> merge (gabung) 2 string
# Out:
# masukkan rating1:4
# masukkan rating2:5
# 45

# %%
rate1 = 4
rate2 = 5

total = rate1 + rate2
print(total)
# integer + integer --> penjumlahan
# Out:
# 9

# %%
# string + integer
a = 'halo'
b = 5
b = str(5) # mengubah tipe data jadi string

hasil = a + b
print('pake +:', hasil)

print(a, b)
# Out:
# pake +: halo5
# halo 5

# %%
# string * int --> ngulang string
hasil = 3 * 'hai' #hai jadi 3x
print(hasil)

# int * int --> perkalian
hasil = 3 * 3
print(hasil)
# Out:
# haihaihai
# 9

# %%
#string * string --> error
hasil = 'a' * 'b'
print(hasil)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-0b08176361bb> in <cell line: 2>()
#       1 #string * string
# ----> 2 hasil = 'a' * 'b'
#       3 print(hasil)
#
# TypeError: can't multiply sequence by non-int of type 'str'
