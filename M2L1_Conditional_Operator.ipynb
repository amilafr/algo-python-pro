# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M2L1_Conditional_Operator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Logical Data Type (Boolean)
#
# [PPT M2L1 ENG](https://docs.google.com/presentation/d/1CntOOhDAPoqIw0QVqVfOlGM8kjyhBYIryeXZUEP3se0/edit?usp=sharing)
#
# [PPT M2L1 IND](https://docs.google.com/presentation/d/1z0d_aTewYql9sFLzcqaLW7-H0skRVakEO3YLSY7nlV4/edit?usp=sharing)

# %% [markdown]
# ## ENG

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## IND

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Example

# %% [markdown]
# **Boolean Variable**

# %%
# boolean variable

like_candy = True
is_sent = False

print(like_candy)
print(is_sent)
# Out:
# True
# False

# %% [markdown]
# **Simple Boolean Expression**

# %%
# boolean expression

cond_1 = 4 > 2 # true
cond_2 = 4 == 2 # false

print(cond_2)
# Out:
# False

# %%
password = 'hello123'
in_pass = input('Enter the password: ')

check_pass = password == in_pass # true

print(check_pass)
# Out:
# Enter the password: hello123
# True

# %%
# integer
hasil = 5 * 2
print(hasil)
# Out:
# 10

# %%
# boolean
hasil = 5 == 2 # sama dengan
print(hasil)
# Out:
# False

# %% [markdown]
# ## Logical Expression

# %% [markdown]
# ### Simple/Sederhana

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_name = 'Lieden'
cond1 = 2 != 3

print(cond1)
# Out:
# True

# %%
# logical operator

greater = 5 > 3 # True
less = 6 < 9 # True

equal = 5 == 7 # False
equal2 = 'hai' == 'halo' # False

not_equal = 5 != 7 # True
not_equal2 = 'hai' != 'halo' # True

less_or_equal = 5 <= 8
greater_or_equal = 6 >= 5

print(equal)
# Out:
# False

# %% [markdown]
# ### Compound/Campuran

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
kondisi1 = 3 < 5 # True
kondisi2 = 'a' != 'b' # True

kond_and = kondisi1 and kondisi2
kond_or = kondisi1 or kondisi2

print(kond_and)
print(kond_or)
# Out:
# True
# True

# %%
cond1 = 2 < 3 # True
cond2 = 'hai' == 'hello' # False

and1 = cond1 and cond2
or1 = cond1 or cond2

print(and1)
print(or1)
# Out:
# False
# True

# %%
# and : True --> 22 nya True
# or : True --> salah 1 bener

kondisi1 = 5 > 3 # True
kondisi2 = 10 < 3 # False

kond_and = kondisi1 and kondisi2

print(kond_and)
# Out:
# False

# %% [markdown]
# #Conditional Operator

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
nama = 'nathan'

# input1 = input('Masukkan nama: ')


if 5 < 2:
  print('namanya benar')
  print('kondisi benar')
else:
  print('kondisi salah')

print('tes')
# Out:
# kondisi salah
# tes

# %%
num1 = int(input('First number: '))
num2 = int(input('Second number: '))

# print Hello if num1 < num2
if num1 < num2: # condition true --> execute action
  print('Hello')
# Out:
# First number: 2
# Second number: 2

# %%
num1 = int(input('First number: '))
num2 = int(input('Second number: '))

# print Hello if num1 < num2
if num1 < num2: # condition true --> execute action
  print('The condition is true')
else: # false
  print('The condition is false')


# if false: print false
# Out:
# First number: 5
# Second number: 5
# The condition is false

# %%
# conditional operator --> if else

angka1 = 10
angka2 = 5

if angka1 < angka2:
  print('Benar')
else: # jika tidak --> opsional
  print('Salaaahh')
# Out:
# Salaaahh
