# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M4L3_Nested_Data_Structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Nested Data Structures
#
# data structure di dalam data structure
#
# [PPT M4L3 IND](https://docs.google.com/presentation/d/1cuHiIYMboOcQLe0kRajajFUAxwYlUXm2ZxpnIcQS730/edit?usp=sharing)
#
# [PPT M4L3 ENG](https://docs.google.com/presentation/d/1b9MJxrRmQrulFVv3oDuv90ebUndJikLO35nPRc2PDeU/edit?usp=sharing)

# %%
# immutable
number = 50

# change --> bikin variabel nya lagi
number = 20

print(number)
# Out:
# 20

# %%
my_tuple = (1, 2, 3)

# my_tuple[0] = 3
my_tuple = (3, 2, 3)

print(my_tuple)
# Out:
# (3, 2, 3)

# %%
# changeable data type
my_list = [1, 2, 3, 4, 4]

my_list.append(5)
my_list[0] = 10

print(my_list)
# Out:
# [10, 2, 3, 4, 4, 5]

# %% [markdown]
# #Lists
#
# Rule: the list item can be an object of any type.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
number_list = [1, 1, 2, 2] # int
dec_list = [0.4, 0.1, 1.5] # decimal/float
string_list = ['alex', 'jane', 'ahmad'] # string

# %% [markdown]
# ## list di dalam list

# %%
list1 = [2, 3, 4, 5]
list2 = ['a', 'b', 'c', 'd']

# list di dalam list
list12 = [[2, 3, 4, 5], ['a', 'b', 'c', 'd']]

print(list12[0])

#2
print(list12[0][1])
# Out:
# [2, 3, 4, 5]
# 3

# %%
numbers = [1, 2, 2, 1]
names = ['hafiz', 'amila', 'ahmad']

# Struktur data bersarang --> struktur data di dalam struktur data

# list di dalam list
list1 = [1, 2, 3, 2, 2]
list2 = ['ab', 'cd']

list3 = [
    [1, 2, 3], # 0
    [3, 4, 5], # 1
    [3, 3, [3, 9]]  # 2
]

print(list1)
print(len(list3))

print(list1[0])

print(list3[2][2][1])
# Out:
# [1, 2, 3, 2, 2]
# 3
# 1
# 9

# %% [markdown]
# ## list --> dict

# %%
# dict --> key-value

student1 = {
    'name': 'lieden',
    'class': 10
}

print(student1)
print(student1['name'])
# Out:
# {'name': 'lieden', 'class': 10}
# lieden

# %%
my_list = [[1, 2, 3], [2, 3, 4]]

my_list_dict = [
    {'name': 'alex', 'class': 10}, # 0
    {'name': 'john', 'class': 11} # 1
]

# %%
students_list = [
    {'name': 'lieden', 'age': 15}, # 0
    {'name': 'amila', 'age': 18}, # 1
    {'name': 'alex', 'age': 16} # 2
]

print(students_list)
print(students_list[0])
print(students_list[0]['name'])
# Out:
# [{'name': 'lieden', 'age': 15}, {'name': 'amila', 'age': 18}, {'name': 'alex', 'age': 16}]
# {'name': 'lieden', 'age': 15}
# lieden

# %%
# list di dalamnya ada dict
my_list = [
    {'nama': 'hafiz', 'umur': 16}, # 0
    {'nama': 'amila', 'umur': 20}, # 1
    {'halo': 'hai'} # 2
]

print(my_list[1]['nama'])
# Out:
# amila

# %% [markdown]
# ## other examples

# %%
my_list = ['a', 'b']

# list di dalam list
my_list = [
    [2, 3, 4, 5],
    [3, 4, 5]
]

# # list --> dictionary
my_list = [
    {'name' : 'Rakha',
     'age': 15},
    {'name': 'Amila',
     'portfolio': ['python', 'xxx']}
]

print(my_list[0]['name'])
# Out:
# Rakha

# %%
# List di dalam list

number_list = [
    [1, 2, 3, 4, 5], # nilai anak 1
    [4, 5, 6], # nilai anak 2
    [3, 4, 5, 6, 7, 8]
]

print(number_list)

cari = number_list[0][4]
print(cari)
# Out:
# [[1, 2, 3, 4, 5], [4, 5, 6], [3, 4, 5, 6, 7, 8]]
# 5

# %%
student_list = [
    {'nama' : 'A',
     'asal' : 'Surabaya'},
    {'nama' : 'B',
     'asal' : 'Jakarta'}
]

cari = student_list[1]['asal']
print(cari)
# Out:
# Jakarta

# %% [markdown]
# #Dictionaries
#
# Rule:
# *   The key can only be an object of an immutable type.
# *   The value can be an object of any type.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
profile = {
    'name': 'lieden',
    'age': 15,
    'hobbies': ['basket', 'football', 'movies'],
    'fav': {'drink': 'water', 'food': 'sushi'}
}

print(profile['hobbies'][2])
print(profile['fav']['drink'])
# Out:
# movies
# water

# %%
data = {
    'nama': 'hafiz',
    'umur' : 16,
    'hobi': 'main bola' # + main bulutangkis
}

# kunci --> cuma bisa data yg immutable / tdk bisa diubah, cth : integer, string, tuple
# nilai --> bebas
data = {
    'nama': 'hafiz',
    'umur' : 16,
    'hobi': ['main bola', 'bulutangkis', 'berenang', '...']
}

print(data['hobi'][1])

data = {
    'nama': 'hafiz',
    'umur' : 16,
    'hobi': {
        'satu': 'main bola', 'dua': 'bulutangkis'
    }
}

print(data['hobi']['dua'])
# Out:
# bulutangkis
# bulutangkis

# %%
data = {
    'nama': 'hafiz',
    'umur' : 16,
    'hobi': ['main bola', 'bulutangkis', 'berenang', '...']
}

print(data['hobi'][1])
# Out:
# bulutangkis

# %%
data = {
    'nama': 'hafiz',
    'umur' : 16,
    'hobi': {
        'satu': 'main bola', 'dua': 'bulutangkis'
    }
}

print(data['hobi']['dua'])
# Out:
# bulutangkis

# %%
#
designers = {
    'John' : '3d designer',
    'Park' : 'graphic designer'
}

designers = {
    'John' : ['a', 'b', 'c'],
    'Park' : {
        'profile': 'tech enthusiast',
        'portfolio': ['a', 'b']
    }
}

print(designers['Park']['portfolio'][1])
# Out:
# b

# %%
# database karyawan

karyawan = {
    'John' : {
        'posisi' : 'manager',
        'skill' : ['python', 'word']
    },
    'James' : {
        'posisi' : 'staff',
        'skill' : ['excel', 'word', 'xxx']
    }
}

cari = karyawan['James']['skill'][0]
print(cari)
# Out:
# excel

# %% [markdown]
# # Task

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
designers = {
    'Johnson' : {
        'profile' : '3D designer',
        'portfolio' : ['GTA', 'World of Tanks']
    },
    'Park' : {
        'profile' : 'Motion designer',
        'portfolio' : ['NFS', 'Minecraft']
    }
}

print(designers['Johnson'])
print(designers['Johnson']['profile'])
print(designers['Johnson']['portfolio'][1])
# Out:
# {'profile': '3D designer', 'portfolio': ['GTA', 'World of Tanks']}
# 3D designer
# World of Tanks

# %% [markdown]
# #Hackathon

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Hackathon IND

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
proteam = {
    'johnson' : {
        'posisi': 'ketua',
        'efektivitas': 8,
        'proyek': ['aplikasi a', 'app b', 'app c']
    },
    'peter': {
        'posisi': 'asisten',
        'efektivitas': 7,
        'proyek': ['aplikasi a', 'app b', 'app z']
    },
    'harry': {
        'posisi': 'ketua',
        'efektivitas': 8,
        'proyek': ['aplikasi a', 'app b', 'app c']
    }
}

print('1. tampil semua nama', '2. cari posisi')
answer = input('Apa yang mau kamu lakukan? -- 0 = off')
while answer != '0':
    if answer == '1':
        print(proteam.keys())

    print('1. tampil semua nama', '2. cari posisi')
    answer = input('Apa yang mau kamu lakukan? -- 0 = off')
