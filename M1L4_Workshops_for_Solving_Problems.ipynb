# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M1L4_Workshops_for_Solving_Problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Nested Constructions
#
# [PPT M1L4 IND](https://docs.google.com/presentation/d/1Ei1Iy5hTRRG-oAGl_Mjp5VRZIzAkGJXkn2G8x3mJCnc/edit?usp=sharing)
#
# [link text](https://docs.google.com/presentation/d/1Ei1Iy5hTRRG-oAGl_Mjp5VRZIzAkGJXkn2G8x3mJCnc/edit?usp=sharing)
#
# Konstruksi di dalam konstruksi / konstruksi bertumpuk

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Example**

# %%
# tidak efektif

rate = input('Rate 1 to 5 about the food:') # string
rate = int(rate) # int

total = rate + 10

print(total)
# Out:
# Rate 1 to 5 about the food:4
# 14

# %%
# efektif
rate = int(input('Rate 1 to 5 about the food:'))

total = rate + 10

print(total)
# Out:
# Rate 1 to 5 about the food:5
# 15

# %%
# 2 baris
name = input("What's your name?")
name_length = len(name)

print('Length of the name :', name_length)
# Out:
# What's your name?Amila
# Length of the name : 5

# %%
# 1 baris
name_length = len(input("What's your name?"))

print('Length of the name :', name_length)
# Out:
# What's your name?Amila
# Length of the name : 5

# %% [markdown]
# #Code Formatting

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Comment**
#
# this is a string in the program that is not viewed by the interpreter.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# ini cara comment untuk 1 baris
# kalo mau nambah baris harus nambahin '#' lagi di depan

'''
kalo ini comment nya bisa berbaris-baris
ini kalo baris bawahnya
ada lagi baris bawahnya
dimulai dan diakhiri sama 3 petik (' / ")
'''

"""
ini kalo petik 2
sama aja yaaa
"""

print('hello world') # comment gak bakal ngaruh ke program
# Out:
# hello world

# %% [markdown]
# #Kunci Jawaban

# %% [markdown]
# #Task 1. Nested constructions

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# 4
feedback = input('Leave a review about the trip:')
feedback = feedback.lower()

print('Review length:', len(feedback))
print('Search for negativity:', feedback.find('terrible'))
# Out:
# Leave a review about the trip:good
# Review length: 4
# Search for negativity: -1

# %%
# 5
price_human = int(input('Plane ticket price:'))
price_luggage = int(input('Luggage price:'))
price_meal = int(input('Price of food on board:'))

total = price_human + price_luggage + price_meal
print('To be paid:', total)
# Out:
# Plane ticket price:1000
# Luggage price:2000
# Price of food on board:1000
# To be paid: 4000

# %%
# 6
name = input("Trainee's name")
tasks_main = int(input('Number of required tasks:'))
tasks_add = int(input('Number of additional tasks:'))

efficiency =  tasks_main * 15 + tasks_add * 20

print(name, '- efficiency', efficiency)
# Out:
# Trainee's nameAmila
# Number of required tasks:3
# Number of additional tasks:2
# Amila - efficiency 85

# %%
# 7
feedback = input('How do you like the internship?')
feedback = feedback.lower()

print('Review length:', len(feedback))
print('Finding flaws:', feedback.find('boring'))
print('Search for advantages:', feedback.find('cool'))
# Out:
# How do you like the internship?great
# Review length: 5
# Finding flaws: -1
# Search for advantages: -1

# %% [markdown]
# #Task 2. "Workshop on problem solving"

# %% [markdown]
# ![image.png](data:image/png;base64,...)
#
# ![image.png](data:image/png;base64,...)

# %%
# 5

#A program for printing interns with whom a contract will be concluded
note = 'Barbara, Michael and Stan performed well during the internship'
offer = note[0:7] + '/' + note[9:16] + '/' + note[21:25]
print('Send a job offer to:', offer)
# Out:
# Send a job offer to: Barbara/Michael/Stan

# %%
# 6 - The program after optimization (other options are possible, in which the program takes the same number of lines or less)

month_salary = int(input('Enter the monthly salary:'))
vacation = int(input('Enter the number of vacation days:'))

daily_salary = month_salary / 29.3 #average number of days in a month
vacation_pay = daily_salary * vacation

print('Approximate vacation pay:', vacation_pay)
# Out:
# Enter the monthly salary:1000
# Enter the number of vacation days:5
# Approximate vacation pay: 170.64846416382252

# %%
# 7 - The program for awarding the award:

salary = int(input('Monthly salary:'))
extra_time = int(input('Number of hours worked on weekends:'))

bonus = salary * 0.01 * extra_time

print('Premium size:', bonus)
# Out:
# Monthly salary:500
# Number of hours worked on weekends:8
# Premium size: 40.0
