# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M4L4_Workshop_for_solving_problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Structures

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Lists

my_list = list()
decimals = [0.5, 9.1, 8.2]
names = ['Sarah', 'Anna', 'Aisha', 'James']

# %%
# Tuples --> immutable

my_tuple = tuple()
decimals = (0.5, 9.1, 8.2)
names = ('Sarah', 'Anna', 'Aisha', 'James')

# %%
# Dictionaries --> key-value pair

my_dict = dict()
identity = {
    'name' : 'James',
    'age' : 18,
    'address' : 'New York'
}

# %%
# Sets

my_set = set()
setA = {1, 2, 2, 7, 7, 3}

print(setA)
# Out:
# {1, 2, 3, 7}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# #Lists
#
# **A list is a structure for storing different types of data in a well-ordered manner.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_list = list()
my_list = [1,3,4,6,2]

print(my_list[2])
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numbers = '1 2 3 4 5'
num_list = numbers.split(' ')

print(num_list)
# Out:
# ['1', '2', '3', '4', '5']

# %% [markdown]
# #Tuples

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_tuple = (3, 2, 4, 5)

my_tuple.remove(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d04b611e2ec3> in <cell line: 3>()
#       1 my_tuple = (3, 2, 4, 5)
#       2
# ----> 3 my_tuple.remove(2)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# #Dictionaries

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_dict = {
    'name' : 'James',
    'age' : 18
}

print(my_dict['name'])
# Out:
# James

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_dict['address'] = 'New York'

print(my_dict)
# Out:
# {'name': 'James', 'age': 18, 'address': 'New York'}

# %%
del my_dict['name']

print(my_dict)
# Out:
# {'age': 18, 'address': 'New York'}

# %% [markdown]
# #Sets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_set = {4, 3, 3, 3, 5, 1, 2}

print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
setA = {1, 2, 3, 4}
setB = {3, 4, 5, 6}

print(setA.union(setB))
print(setA.intersection(setB))

# difference
a = setA.difference(setB)
b = setB.difference(setA)

print(a)
print(b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {5, 6}
