# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M4L4_Workshop_for_solving_problems.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data Structures
#
# [PPT M4L4 IND](https://docs.google.com/presentation/d/1RuD20NMex6LTaPHkHLtnfd4tLxqSLbh6cuztnQSYZuA/edit?usp=sharing)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Lists --> urut (punya index) dan bisa diubah

my_list = list() # list kosong
my_list = [9, 9, 10, 11] # udah ada datanya

# %%
# Tuples --> urut dan tidak bisa diubah

my_tuple = tuple()
my_tuple = (1, 2, 1)

# %%
# Dictionaries --> pasangan kunci-nilai

my_dict = dict()
my_dict = {
    # kunci : nilai,
    'nama': 'Amila',
    'asal': 'Jakarta'
}

# %%
# Set --> datanya unik (gak ada yang sama)

my_set = set()
my_set = {2, 3, 2, 1, 2} # data yang dobel2 dianggap cuma 1

print(my_set)

my_set.remove(2)
print(my_set)
# Out:
# {1, 2, 3}
# {1, 3}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# tidak bisa diubah
nama = 'Nafiz' # string gabisa diubah pake coding
nama = 'Hafiz' # kalo ubah

list_nama = ['hafiz', 'adam']
list_nama[1] = 'lisa' # list --> bisa diubah datanya pakai coding

print(list_nama)
# Out:
# ['hafiz', 'lisa']

# %% [markdown]
# #Lists
#
# **A list is a structure for storing different types of data in a well-ordered manner.**

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_list = list()
my_list = [1, 3, 4, 6, 2]

# ambil data--> pake index
print(my_list[2])
# Out:
# 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
students = ['smith', 'peterson', 'langdon']

# nambah data --> di akhir
students.append('lisa')

# hapus data
students.remove('peterson')

# mengurutkan data sesuai abjad/angka
students.sort()

# ngecek datanya ada atau nggak di list
cari = 'smith' in students # cari nama smith

print(students)
print(cari)
# Out:
# ['langdon', 'lisa', 'smith']
# True

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# split --> string jadi list (datanya diambil dari pemisah)

numbers = input('Masukkan angka-angkanya: ')
numbers = numbers.split('-') # pemisahnya spasi

print(numbers)
# Out:
# Masukkan angka-angkanya: 2-2-2-3
# ['2', '2', '2', '3']

# %%
numbers = '1 2 3 4 5'
num_list = numbers.split(' ')

print(num_list)
# Out:
# ['1', '2', '3', '4', '5']

# %% [markdown]
# #Tuples

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_tuple = (3, 2, 4, 5)

my_tuple.remove(2)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-4-d04b611e2ec3> in <cell line: 3>()
#       1 my_tuple = (3, 2, 4, 5)
#       2
# ----> 3 my_tuple.remove(2)
#
# AttributeError: 'tuple' object has no attribute 'remove'

# %% [markdown]
# #Dictionaries

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# {kunci: nilai}
data = {
    'nama': 'Hafiz',
    'umur': 16,
    'hobi': 'main bola'
}

print(data['nama'])
# Out:
# Hafiz

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
data = {
    'nama': 'Hafiz',
    'umur': 16,
    'hobi': 'main bola'
}

# panjang data
panjang = len(data)
print(panjang)

# ambil data --> pake kunci
print(data['nama'])
# Out:
# 3
# Hafiz

# %%
# nambah data
data['asal'] = 'Sumatra'

print(data)
# Out:
# {'nama': 'Hafiz', 'umur': 16, 'hobi': 'main bola', 'asal': 'Sumatra'}

# %%
# hapus
del data['hobi']

# %%
print(data)
# Out:
# {'nama': 'Hafiz', 'umur': 16, 'asal': 'Sumatra'}

# %% [markdown]
# #Sets

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
my_set = {4, 3, 3, 3, 5, 1, 2}

print(my_set)
# Out:
# {1, 2, 3, 4, 5}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
setA = {1, 2, 3, 4}
setB = {3, 4, 5, 6}

print(setA.union(setB))
print(setA.intersection(setB))

# difference
a = setA.difference(setB)
b = setB.difference(setA)

print(a)
print(b)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {5, 6}
