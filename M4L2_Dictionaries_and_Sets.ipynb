# %% [markdown]
# <a href="https://colab.research.google.com/github/amilafr/algo-python-pro/blob/main/M4L2_Dictionaries_and_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Dictionaries and Sets
# [PPT M4L2 IND](https://docs.google.com/presentation/d/1d1HFA0jEwtGrAQlqOZF942So22vs7q_eCPO-d85HCGg/edit?usp=sharing)
#
# [PPT M4L2 ENG](https://docs.google.com/presentation/d/1ePjq8bxUcKCgO3IQYat9eHKUEkWg8gkikbcgtfCXRc0/edit?usp=sharing)

# %% [markdown]
# #Dictionaries
#
# **An unordered set of key-value pairs.**
#
# cth : nyari buku berdasarkan genre

# %%
number_list = [1, 2, 3, 4, 2, 5] # list --> index

print(number_list[2])
# Out:
# 3

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# empty dict
movies = dict()

# movies group by genre
movies = {
    'romance' : 'Titanic', # key : value
    'horror' : 'The Conjuring',
    'sci-fi' : 'Interstellar'
}

# conjuring
print(movies['horror'])
# Out:
# The Conjuring

# %%
# list
data = ['amila', 'nathan', 'putri']

print(data[1])
# Out:
# nathan

# %%
# dictionary --> pasangan key-value
data = {'nama': 'Nathan', 'umur': 16, 'alamat': 'Bali'}

# nama_dict[key]
print(data['umur'])
# Out:
# 16

# %%
data_film = {
    'horror': 'The Conjuring',
    'romance': 'Titanic',
    'fantasy': 'Harry Potter'
}

print(data_film['fantasy'])
# Out:
# Harry Potter

# %%
print(data_film.keys())
# Out:
# dict_keys(['horror', 'romance', 'fantasy'])

# %%
print(data_film.values())
# Out:
# dict_values(['The Conjuring', 'Titanic', 'Harry Potter'])

# %%
print(len(data_film))
# Out:
# 3

# %%
data_film['horror'] = 'The Nun'

print(data_film)
# Out:
# {'horror': 'The Nun', 'romance': 'Titanic', 'fantasy': 'Harry Potter'}

# %%
# nambahin key 'sci-fi'
data_film['sci-fi'] = 'Lucy'

print(data_film)
# Out:
# {'horror': 'The Nun', 'romance': 'Titanic', 'fantasy': 'Harry Potter', 'sci-fi': 'Lucy'}

# %%
# apakah ada key-nya di dict
cari = 'fantasy' in data_film

print(cari)
# Out:
# True

# %%
print(data_film['fantasy'])
# Out:
# Harry Potter

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Length

# %%
# Length
movies = {
    'romance' : 'Titanic', # key : value
    'horror' : 'The Conjuring',
    'sci-fi' : 'Interstellar'
}

length = len(movies) # number of pairs

print(length)
# Out:
# 3

# %% [markdown]
# Get all keys

# %%
movies_keys = movies.keys()

print(movies_keys)
# Out:
# dict_keys(['romance', 'horror', 'sci-fi'])

# %% [markdown]
# Get all values

# %%
print(movies.values())
# Out:
# dict_values(['Titanic', 'The Conjuring', 'Interstellar'])

# %%
# item stock
item_stock = {
    'book' : 10,
    'pencil': 100,
    'eraser': 50
}

print(item_stock['pencil'])
# Out:
# 100

# %% [markdown]
# ## ex

# %%
buku = dict()
print(buku)

buku['fiksi'] = 'haha'
print(buku)
# Out:
# {}
# {'fiksi': 'haha'}

# %%
# dictionary --> buku berdasarkan genre
buku = {
    'romance' : 'Dilan',
    'horror' : 'The conjuring',
    'mystery' : 'Conan'
}

# print(buku['romance'])
genre = input('Pilih genre buku: ')
print(buku[genre])
# Out:
# Pilih genre buku: horror
# The conjuring

# %%
my_list = [2, 2, 3, 4, 5] # list --> datanya urut

print(my_list)
# Out:
# [2, 2, 3, 4, 5]

# %%
print(my_list[3])
# Out:
# 4

# %%
numbers = [1, 3, 4, 5, 6]

print(numbers[2])
# Out:
# 4

# %%
print(len(numbers))
# Out:
# 5

# %%
print(1 in numbers)
# Out:
# True

# %% [markdown]
# ## commands in dictionaries

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# dictionary movies based on genre
movies = {
    'romance' : 'Titanic', # key : value
    'horror' : 'The Conjuring',
    'sci-fi' : 'Interstellar'
}
print(movies)

# add data --> key-value pair
# dict_name[key] = value
movies['thriller'] = 'Dont breathe'

print(movies)
# Out:
# {'romance': 'Titanic', 'horror': 'The Conjuring', 'sci-fi': 'Interstellar'}
# {'romance': 'Titanic', 'horror': 'The Conjuring', 'sci-fi': 'Interstellar', 'thriller': 'Dont breathe'}

# %%
# search key in dict (True/False)

check = 'thriller' in movies # key in dict_name

print(check)
# Out:
# False

# %%
print(movies)
# Out:
# {'romance': 'Titanic', 'horror': 'The Conjuring', 'sci-fi': 'Interstellar', 'thriller': 'Dont breathe'}

# %%
# remove data
del movies['horror']

print(movies)
# Out:
# {'romance': 'Titanic', 'sci-fi': 'Interstellar', 'thriller': 'Dont breathe'}

# %% [markdown]
# ## ex2

# %%
buku = {
    'horror' : 'The Conjuring',
    'romance' : 'Dilan'
    }

print(buku)
# Out:
# {'horror': 'The Conjuring', 'romance': 'Dilan'}

# %%
buku['fiksi'] = 'Maze Runner'

print(buku)
# Out:
# {'horror': 'The Conjuring', 'romance': 'Dilan', 'fiksi': 'Maze Runner'}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Nyari data --> pake kata kunci

buku = {
    'horror' : 'The Conjuring',
    'romance' : 'Maze Runner',
    'fiksi' : 'Maze Runner',
    # 'fiksi':''
    }

search = buku['romance'] # dict_variable[key]
print(search)
# Out:
# Maze Runner

# %%
print(buku)
# Out:
# {'horror': 'The Conjuring', 'romance': 'Maze Runner', 'fiksi': 'Maze Runner'}

# %%
# nyari kunci ada/gak di dict
cari = 'horror' in buku
print(cari)
# Out:
# True

# %%
# Panjang dictionaries

buku = {
    'horror' : 'The Conjuring',
    'romance' : 'Maze Runner',
    'fiksi' : 'Maze Runner',
    }

length = len(buku) # sama kyk list --> len()
print(length)
# Out:
# 3

# %%
# Get keys --> ambil semua keys (kunci) di dictionary

print(buku.keys()) # dict_variable.keys()
# Out:
# dict_keys(['horror', 'romance', 'fiksi'])

# %%
# Get values --> ambil semua values di dictionary

print(buku.values()) # dict_variable.values()
# Out:
# dict_values(['The Conjuring', 'Maze Runner', 'Maze Runner'])

# %%
# Nambahin data -- key + value in dictionary

# nambah data --> key = 'non fiction', value = 'Michael Jackson'
buku['nonfiction'] = 'Michael Jackson'

print(buku)
# Out:
# {'horror': 'The Conjuring', 'romance': 'Maze Runner', 'fiksi': 'Maze Runner', 'nonfiction': 'Michael Jackson'}

# %%
# Delete key and its value

del buku['romance']

print(buku)
# Out:
# {'horror': 'The Conjuring', 'fiksi': 'Maze Runner', 'nonfiction': 'Michael Jackson'}

# %%
print(buku)
# Out:
# {'romance': 'Dilan', 'nonfiction': 'Michael Jackson'}

# %%
# Nyari key --> True or False

cari_horror = 'horror' in buku
print(cari_horror)

cari_romance = 'romance' in buku
print(cari_romance)
# Out:
# False
# True

# %% [markdown]
# ## Review

# %%
# Dictionary --> struktur data yang tidak berurutan (tidak ada index)
# --> pasangan - key : value
# nama_dict = {key : value}

data_film = {
    'horror': 'The Nun',
    'romance': 'Romeo and Juliet',
    'comedy': 'Spy'
}

data = {
    'nama': 'Nathan',
    'umur': 16,
    'alamat': 'Bali'
}

# %% [markdown]
# #Sets
# **An unordered set of unique elements.**
#
# setiap data yang ada tidak boleh sama
# (mirip himpunan)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# list --> ada index
number_list = [3, 3, 4, 1, 2, 1]

print(number_list)
# Out:
# [3, 3, 4, 1, 2, 1]

# %%
# set --> tidak ada index
# otomatis jadi unik (elemennya tidak ada yg sama dan otomatis berurut)
number_set = {3, 3, 4, 1, 2, 1}

print(number_set)
# Out:
# {1, 2, 3, 4}

# %%
numbers = set() # set kosong

# %%
# bikin set dari list

number_list = [3, 3, 4, 1, 2, 1]
print(number_list)

# nama_set = set(nama_list)

number_set = set(number_list)
print(number_set)
# Out:
# [3, 3, 4, 1, 2, 1]
# {1, 2, 3, 4}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
numbers_list = [1, 2, 2, 1, 1, 1]

print(numbers_list)
# Out:
# [1, 2, 2, 1, 1, 1]

# %%
numbers = set() # empty set
numbers = {1, 2, 2, 1, 1, 1, 3, 3, 3} # unique elements

print(numbers)
# Out:
# {1, 2, 3}

# %%
# Length of a Set
length = len(numbers) # sama

print(length)
# Out:
# 3

# %%
# change list --> set

number_list = [2, 2, 3, 3, 1, 1, 4, 2]
print(number_list)
print('length of list:', len(number_list))

number_set = set(number_list) # change list --> set
print(number_set)
print('length of set:', len(number_set))
# Out:
# [2, 2, 3, 3, 1, 1, 4, 2]
# length of list: 8
# {1, 2, 3, 4}
# length of set: 4

# %%
# Bikin Set dari Data Structure lain

# List --> Set
my_list = [1, 2, 3, 3, 4, 2, 1]
my_set = set(my_list) # set(nama_list)

print(my_list)
print('panjang list:', len(my_list))

print(my_set)
print('panjang set:', len(my_set))
# Out:
# [1, 2, 3, 3, 4, 2, 1]
# panjang list: 7
# {1, 2, 3, 4}
# panjang set: 4

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
set1 = {1, 2, 3}
print(set1)

# menambah elemen ke set
# nama_set.add(elemen yang mau ditambah)
set1.add(4)
set1.add(-4)

print(set1)
# Out:
# {1, 2, 3}
# {1, 2, 3, 4, -4}

# %%
# menghapus elemen di set
# nama_set.remove(elemen yang mau dihapus)
set1.remove(-4)

print(set1)
# Out:
# {1, 2, 3, 4}

# %%
# iterate
for angka in set1:
  print(angka)
# Out:
# 1
# 2
# 3
# 4

# %%
set1 = {1, 2, 3}

# mencari elemen di set (apakah ada atau tidak)
cari = 4 in set1
# ada --> True
# gak ada --> False

print(cari)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Add and Remove Element in Set

set_number = {1, 2, 3}

set_number.add(4) # add element
print(set_number)
# Out:
# {1, 2, 3, 4}

# %%
# remove
set_number.remove(2) # set_name.remove(value)

print(set_number)
# Out:
# {1, 3, 4}

# %%
# clear all elements
set_number.clear() # kehapus semua --> set kosong

print(set_number) # --> empty set
# Out:
# set()

# %%
# Search element in Set --> True or False

my_set = {1, 2, 3}

# cek elemen
check = 4 in my_set

print(check)
# Out:
# False

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# union --> gabungan/kombinasi
a_union_b = A.union(B)
print(a_union_b)

# intersection --> irisan
a_inter_b = A.intersection(B)
print(a_inter_b)

# difference

# A difference B --> ada di A, tidak ada di B
a_diff_b = A.difference(B)
print(a_diff_b)

# B difference A --> ada di B, tidak ada di A
b_diff_a = B.difference(A)
print(b_diff_a)
# Out:
# {1, 2, 3, 4, 5, 6}
# {3, 4}
# {1, 2}
# {5, 6}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
A = {1, 2, 3, 4}
B = {3, 4, 5, 6}

# %%
# Union --> combination/gabungan set A dan B
union_ab = A.union(B)

print(union_ab)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
# Intersection --> Irisan (Nilai yang sama) / same value
inter_ab = A.intersection(B)

print(inter_ab)
# Out:
# {3, 4}

# %%
# Difference --> yang gak sama
a_diff_b = A.difference(B) # included in A, not included in B

print(a_diff_b)
# Out:
# {1, 2}

# %%
b_diff_a = B.difference(A) # included in B, not included in A

print(b_diff_a)
# Out:
# {5, 6}

# %% [markdown]
# # Solutions

# %% [markdown]
# ## 1.3

# %%
books = {
  'King': 'It',
  'London': 'White Fang',
  'Carroll': 'Alice in Wonderland',
  'Lindgren': 'Karlsson on the Roof'}


books['Defoe'] = 'The Adventures of Robinson Crusoe'
books['Dumas'] = 'The Count of Monte Cristo'
del books['King']


if 'Defoe' in books and 'Dumas' in books:
   print('Basis data telah diperbarui!')
if ('King' in books) == False:
   print('Preferensi telah diperbarui')
# Out:
# Basis data telah diperbarui!
# Preferensi telah diperbarui

# %% [markdown]
# ## 1.4

# %%
authors = {
   'Kipling' : 'Novelis Inggris, penulis cerita pendek, penyair, dan jurnalis. Salah satu tokoh sastra paling otoritatif, dia adalah salah satu penulis paling populer di Britania Raya pada akhir abad ke-19 dan awal abad ke-20',
   'Tolkien': 'Penulis Inggris, penyair, filolog, dan akademisi, paling dikenal sebagai penulis karya fantasi The Hobbit dan The Lord of the Rings.',
   'Camus' : 'Filusuf, penulis, dramawan, dan jurnalis Perancis. Dianugerahi Hadiah Nobel untuk Sastra pada tahun 1957'}


surname = input('Nama belakang penulis:')
if surname in authors:
   print('Biografi:', authors[surname])
else:
    answer = input('Penulis tidak ditemukan. Ingin menambahkan?')
    answer = answer.lower()
    if answer == 'ya':
        biography = input('Biografi penulis:')
        authors[surname] = biography
        print(authors)
    else:
        print('Tanggapan diterima')
# Out:
# Nama belakang penulis:Tolkien
# Biografi: Penulis Inggris, penyair, filolog, dan akademisi, paling dikenal sebagai penulis karya fantasi The Hobbit dan The Lord of the Rings.

# %% [markdown]
# ## 1.5

# %%
student_card = {'angka': '324', 'nama belakang': 'Smith'}
print('Selamat datang!', student_card)

answer = int(input('Akun pribadi: 1 - ambil buku, 2 - kembalikan buku, 3 - pulang'))

while answer != 3:
  if answer == 1:
      title = input('Masukkan judul:')
      student_card['utang'] = title
      print('Kartu pembaca:', student_card)
  if answer == 2:
      if 'utang' in student_card:
          del student_card['utang']
      print('Kartu pembaca:', student_card)
  answer = int(input('Tindakan Anda: 1 - ambil buku, 2 - kembalikan buku, 3 - pulang'))

print('Sampai jumpa lagi:', student_card)
# Out:
# Selamat datang! {'angka': '324', 'nama belakang': 'Smith'}
# Akun pribadi: 1 - ambil buku, 2 - kembalikan buku, 3 - pulang1
# Masukkan judul:angka
# Kartu pembaca: {'angka': '324', 'nama belakang': 'Smith', 'utang': 'angka'}
# Tindakan Anda: 1 - ambil buku, 2 - kembalikan buku, 3 - pulang3
# Sampai jumpa lagi: {'angka': '324', 'nama belakang': 'Smith', 'utang': 'angka'}

# %% [markdown]
# ## 2.5

# %%
def application():
    contestants = dict()
    name = input('Masukkan nama peserta (0 - lengkap)')
    while name != '0':
        poem = input('Masukkan judul karya')
        contestants[name] = poem
        name = input('Masukkan nama peserta (0 - lengkap)')
    return contestants

def get_artists(poem):
    artists = []
    for artist in contestants:
        if contestants[artist] == poem:
            artists.append(artist)
        artists.sort()
    return '(' + ', '.join(artists) + ')'

contestants = application()
concert_program = set(contestants.values())
print('PROGRAM KONSER')
for item in concert_program:
    print(item, get_artists(item))
# Out:
# Masukkan nama peserta (0 - lengkap)james
# Masukkan judul karyahello
# Masukkan nama peserta (0 - lengkap)zayne
# Masukkan judul karyahai
# Masukkan nama peserta (0 - lengkap)0
# PROGRAM KONSER
# hello (james)
# hai (zayne)
